# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import platform
from matplotlib import font_manager, rc
from insert_XY import insertXY

import googlemaps
gmaps = googlemaps.Client(key='AIzaSyCoLfrAJNvN7zqZpqNGby1xYuZTOzkOGf0')

# %%
# 자치단체 주차장 현황 data 삽입
park = pd.read_csv('final_data.csv')

# %%
park.rename(columns={"9.22(토)":"9_22(토)",
                  "9.23(일)":"9_23(일)",
                    "9.24(월)":"9_24(월)",
                    "9.25(화)":"9_25(화)",
                    "9.26(수)":"9_26(수)"}, inplace=True)

# %%
# 자치단체 주차장 현황 data 삽입
school = pd.read_csv('final_data_school.csv')

# %%
school
# Out:
#       Unnamed: 0    시도           주차장명 주차장유형                             주소  \
# 0              0   강원도         강동초등학교    노상             강원도 강릉시 강동면 단경길 20
# 1              1   강원도         강릉초등학교    노상                강원도 강릉시 토성로 103
# 2              2   강원도         성덕초등학교    부설                 강원도 강릉시 용지로 60
# 3              3   강원도         송양초등학교    노외            강원도 강릉시 성산면 위촌길 198
# 4              4   강원도         신영초등학교    노상                강원도 강릉시 주문북로160
# 5              5   강원도         신왕초등학교    부설       강원도 강릉시 연곡면 진고개로 2265-11
# 6              6   강원도         옥계초등학교    노상           강원도 강릉시 옥계면 옥계로 1074
# 7              7   강원도         옥천초등학교    노상                  강원도 강릉시 수문길25
# 8              8   강원도    옥천초등학교운산분교장    노상              강원도 강릉시 운산길 79-15
# 9              9   강원도         율곡초등학교    노상                강원도 강릉시 원대로 129
# 10            10   강원도         중앙초등학교    부설                강원도 강릉시 성덕포남로18
# ...

# %%
combined = pd.merge(park, school, how='outer')

# %%
combined
# Out:
#        Unnamed: 0    시도               주차장명 주차장유형                           주소  \
# 0               0  충청북도          충북도청부설주차장    부설          충청북도 청주시 상당구 상당로 82
# 1               1  충청북도        청주시청 부설 주차장    부설  충청북도 청주시 상당구 상당고 155(북문로3가)
# 2               2  충청북도           청주시 청원구청    부설        충청북도 청주시 청원구 직지대로 871
# 3               3  충청북도          어린이회관 주차장    부설        충청북도 청주시 상당구 명암동 73-4
# 4               4  충청북도        청주시립미술관 주차장    노외      충청북도 청주시 서원구 충렬로18번길 50
# 5               5  충청북도           청주시 상당구청    부설      충청북도 청주시 상당구 상당로69번길 38
# 6               6  충청북도     청주 체육시설 부설 주차장    부설   충청북도 청주시 서원구 사직동 808 번지 일대
# 7               7  충청북도           청주시 흥덕구청    부설    충청북도 청주시 흥덕구 복대1동 대농로 88
# 8               8  충청북도           청주시 서원구청    부설        충청북도 청주시 서원구 사직대로 227
# 9               9  충청북도  청주시 농업기술센터 야외 운동장    노외     충청북도 청주시 상당구 남일면 단재로 480
# 10             10  충청북도        충주천 제3공영주차장    노외               충청북도 충주시 지현동 6
# ...

# %%
for cols in park.keys():
    if 'Unnamed' in cols:
        del combined[cols]

# %%
combined
# Out:
#        Unnamed: 0    시도               주차장명 주차장유형                           주소  \
# 0               0  충청북도          충북도청부설주차장    부설          충청북도 청주시 상당구 상당로 82
# 1               1  충청북도        청주시청 부설 주차장    부설  충청북도 청주시 상당구 상당고 155(북문로3가)
# 2               2  충청북도           청주시 청원구청    부설        충청북도 청주시 청원구 직지대로 871
# 3               3  충청북도          어린이회관 주차장    부설        충청북도 청주시 상당구 명암동 73-4
# 4               4  충청북도        청주시립미술관 주차장    노외      충청북도 청주시 서원구 충렬로18번길 50
# 5               5  충청북도           청주시 상당구청    부설      충청북도 청주시 상당구 상당로69번길 38
# 6               6  충청북도     청주 체육시설 부설 주차장    부설   충청북도 청주시 서원구 사직동 808 번지 일대
# 7               7  충청북도           청주시 흥덕구청    부설    충청북도 청주시 흥덕구 복대1동 대농로 88
# 8               8  충청북도           청주시 서원구청    부설        충청북도 청주시 서원구 사직대로 227
# 9               9  충청북도  청주시 농업기술센터 야외 운동장    노외     충청북도 청주시 상당구 남일면 단재로 480
# 10             10  충청북도        충주천 제3공영주차장    노외               충청북도 충주시 지현동 6
# ...

# %%
combined['9_22(토)'][10119]
# Out:
# '22,09:00~상시개방'

# %%
# final.csv를 저장
combined.to_csv('./data/final_data_chu.csv', encoding='utf-8-sig')
